# %%
# !pip install pymongo
# !pip install requests
# !pip install flipside

# %%
import requests
from pymongo import MongoClient

# %%
from flipside import Flipside

# %%
client = MongoClient(
    "mongodb+srv://pp36Gies:Gies2023@cluster0.7yo5viv.mongodb.net/?sslCipherSuites=TLS_RSA_WITH_AES_128_CBC_SHA256")
db = client["FLIPSIDE_NFT"]
collection = db["Cryptopunks"]
# Out:
# /usr/local/lib/python3.10/dist-packages/pymongo/uri_parser.py:321: UserWarning: Unknown option sslciphersuites
#   return get_validated_options(opts, warn)

# %%
# Initialize `Flipside` with your API Key and API Url - first 5000 rows - leaving out attribute tx_fee and tx_fee_usd
flipside = Flipside("4673401c-ee75-4514-a248-7b8a7e7450cc", "https://api-v2.flipsidecrypto.xyz")

sql = """
  select
  sales.BLOCK_NUMBER,
  sales.BLOCK_TIMESTAMP,
  sales.TX_HASH,
  sales.EVENT_TYPE,
  sales.PLATFORM_ADDRESS,
  sales.PLATFORM_NAME,
  sales.PLATFORM_EXCHANGE_VERSION,
  sales.AGGREGATOR_NAME,
  sales.SELLER_ADDRESS,
  sales.BUYER_ADDRESS,
  sales.NFT_ADDRESS,
  sales.PROJECT_NAME,
  sales.ERC1155_VALUE,
  sales.TOKENID,
  sales.TOKEN_METADATA,
  sales.CURRENCY_SYMBOL,
  sales.CURRENCY_ADDRESS,
  sales.PRICE,
  sales.PRICE_USD,
  sales.TOTAL_FEES,
  sales.PLATFORM_FEE,
  sales.CREATOR_FEE,
  sales.TOTAL_FEES_USD,
  sales.PLATFORM_FEE_USD,
  sales.CREATOR_FEE_USD,
  sales.ORIGIN_FROM_ADDRESS,
  sales.ORIGIN_TO_ADDRESS,
  sales.ORIGIN_FUNCTION_SIGNATURE,
  meta.BLOCKCHAIN,
  meta.COMMISSION_RATE,
  meta.CONTRACT_ADDRESS,
  meta.CONTRACT_NAME,
  meta.CREATED_AT_BLOCK_NUMBER,
  meta.CREATED_AT_TIMESTAMP,
  meta.CREATED_AT_TX_HASH,
  meta.CREATOR_ADDRESS,
  meta.CREATOR_NAME,
  meta.PROJECT_NAME,
  meta.TOKEN_ID,
  meta.TOKEN_METADATA,
  meta.TOKEN_METADATA_URI,
  meta.TOKEN_NAME
from
  ethereum.nft.dim_nft_metadata meta,
  ethereum.nft.ez_nft_sales sales
where
  meta.token_name like ('%cryptopunks%')
  and sales.tokenid = meta.token_id
  and sales.platform_name like ('opensea')
  LIMIT 5000
"""

# %%
query_result_set = flipside.query(sql)

# %%
print(type(query_result_set))
# Out:
# <class 'flipside.models.query_result_set.QueryResultSet'>

# %%
import pandas as pd

# %%
df = pd.DataFrame(query_result_set.rows, columns = query_result_set.columns)

# Display the DataFrame
print(df)
# Out:
#       block_number           block_timestamp  \
# 0         13664894  2021-11-22T13:58:11.000Z
# 1         13947667  2022-01-05T20:45:34.000Z
# 2         13916202  2022-01-01T00:06:40.000Z
# 3         14227021  2022-02-18T01:00:09.000Z
# 4         14194698  2022-02-13T01:05:36.000Z
# ...            ...                       ...
# 4995      14434070  2022-03-22T04:51:51.000Z
# 4996      14437425  2022-03-22T17:21:11.000Z
# 4997      14268244  2022-02-24T10:25:02.000Z
# 4998      14265750  2022-02-24T01:04:31.000Z
# 4999      14271123  2022-02-24T21:00:49.000Z
#
#                                                 tx_hash event_type  \
# 0     0x46f26736f9d5f2f0a887c8ece9ed73f3c39db1dc4356...       sale
# 1     0x6250ef04a7c8e6cd9ca32864827631af9772018d6e95...    bid_won
# 2     0x0973487976a6b8427abbeeb568e256650297789da415...       sale
# 3     0xaa4ba79d892b86f8375afa4cb0ac5cba23262b644107...       sale
# 4     0x63ff954e57b255abe117710726c726c42da4b5f8e0b1...       sale
# ...

# %%
df.shape[0]
# Out:
# 5000

# %%
# Assuming 'df' is your DataFrame
data = df.to_dict(orient='records')

# %%
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('656a868692fddc4774666891'), ObjectId('656a868692fddc4774666892'), ObjectId('656a868692fddc4774666893'), ObjectId('656a868692fddc4774666894'), ObjectId('656a868692fddc4774666895'), ObjectId('656a868692fddc4774666896'), ObjectId('656a868692fddc4774666897'), ObjectId('656a868692fddc4774666898'), ObjectId('656a868692fddc4774666899'), ObjectId('656a868692fddc477466689a'), ObjectId('656a868692fddc477466689b'), ObjectId('656a868692fddc477466689c'), ObjectId('656a868692fddc477466689d'), ObjectId('656a868692fddc477466689e'), ObjectId('656a868692fddc477466689f'), ObjectId('656a868692fddc47746668a0'), ObjectId('656a868692fddc47746668a1'), ObjectId('656a868692fddc47746668a2'), ObjectId('656a868692fddc47746668a3'), ObjectId('656a868692fddc47746668a4'), ObjectId('656a868692fddc47746668a5'), ObjectId('656a868692fddc47746668a6'), ObjectId('656a868692fddc47746668a7'), ObjectId('656a868692fddc47746668a8'), ObjectId('656a868692fddc47746668a9'), ObjectId('656a868692fddc477466
# ...

# %%
# Initialize `Flipside` with your API Key and API Url - last 5000 - leaving out attribute tx_fee and tx_fee_usd
flipside = Flipside("4673401c-ee75-4514-a248-7b8a7e7450cc", "https://api-v2.flipsidecrypto.xyz")

sql = """
  select
  sales.BLOCK_NUMBER,
  sales.BLOCK_TIMESTAMP,
  sales.TX_HASH,
  sales.EVENT_TYPE,
  sales.PLATFORM_ADDRESS,
  sales.PLATFORM_NAME,
  sales.PLATFORM_EXCHANGE_VERSION,
  sales.AGGREGATOR_NAME,
  sales.SELLER_ADDRESS,
  sales.BUYER_ADDRESS,
  sales.NFT_ADDRESS,
  sales.PROJECT_NAME,
  sales.ERC1155_VALUE,
  sales.TOKENID,
  sales.TOKEN_METADATA,
  sales.CURRENCY_SYMBOL,
  sales.CURRENCY_ADDRESS,
  sales.PRICE,
  sales.PRICE_USD,
  sales.TOTAL_FEES,
  sales.PLATFORM_FEE,
  sales.CREATOR_FEE,
  sales.TOTAL_FEES_USD,
  sales.PLATFORM_FEE_USD,
  sales.CREATOR_FEE_USD,
  sales.ORIGIN_FROM_ADDRESS,
  sales.ORIGIN_TO_ADDRESS,
  sales.ORIGIN_FUNCTION_SIGNATURE,
  meta.BLOCKCHAIN,
  meta.COMMISSION_RATE,
  meta.CONTRACT_ADDRESS,
  meta.CONTRACT_NAME,
  meta.CREATED_AT_BLOCK_NUMBER,
  meta.CREATED_AT_TIMESTAMP,
  meta.CREATED_AT_TX_HASH,
  meta.CREATOR_ADDRESS,
  meta.CREATOR_NAME,
  meta.PROJECT_NAME,
  meta.TOKEN_ID,
  meta.TOKEN_METADATA,
  meta.TOKEN_METADATA_URI,
  meta.TOKEN_NAME
from
  ethereum.nft.dim_nft_metadata meta,
  ethereum.nft.ez_nft_sales sales
where
  meta.token_name like ('%cryptopunks%')
  and sales.tokenid = meta.token_id
  and sales.platform_name like ('opensea')
Order by sales.BLOCK_TIMESTAMP Desc
Limit 5000
"""

# %%
query_result_set = flipside.query(sql)

# %%
df = pd.DataFrame(query_result_set.rows, columns = query_result_set.columns)

# Display the DataFrame
print(df)
# Out:
#       block_number           block_timestamp  \
# 0         18694489  2023-12-01T22:17:35.000Z
# 1         18689881  2023-12-01T06:49:11.000Z
# 2         18683649  2023-11-30T09:52:11.000Z
# 3         18677965  2023-11-29T14:47:47.000Z
# 4         18676443  2023-11-29T09:41:59.000Z
# ...            ...                       ...
# 4995      18552575  2023-11-12T01:31:47.000Z
# 4996      18552575  2023-11-12T01:31:47.000Z
# 4997      18552228  2023-11-12T00:21:35.000Z
# 4998      18546574  2023-11-11T05:21:47.000Z
# 4999      18543308  2023-11-10T18:23:47.000Z
#
#                                                 tx_hash event_type  \
# 0     0xa8dcc3a27c80999829f6ba219767536da4f7a3a1c23e...    bid_won
# 1     0x56b5168969c33c0ade05d4f7f52311e65cfbd6b64d51...       sale
# 2     0xc70bb9a447961436ff064255b00fd706abf0c1859c4d...    bid_won
# 3     0xf5e6ebe5aaab39ec0e3fbd7910562f04bd0f5a2a1b06...       sale
# 4     0x02db5589ddc3ad0c8d675f6ef5b9fff5f84c1f29fbd5...    bid_won
# ...

# %%
# Assuming 'df' is your DataFrame
data = df.to_dict(orient='records')

# %%
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('656a871392fddc4774667c19'), ObjectId('656a871392fddc4774667c1a'), ObjectId('656a871392fddc4774667c1b'), ObjectId('656a871392fddc4774667c1c'), ObjectId('656a871392fddc4774667c1d'), ObjectId('656a871392fddc4774667c1e'), ObjectId('656a871392fddc4774667c1f'), ObjectId('656a871392fddc4774667c20'), ObjectId('656a871392fddc4774667c21'), ObjectId('656a871392fddc4774667c22'), ObjectId('656a871392fddc4774667c23'), ObjectId('656a871392fddc4774667c24'), ObjectId('656a871392fddc4774667c25'), ObjectId('656a871392fddc4774667c26'), ObjectId('656a871392fddc4774667c27'), ObjectId('656a871392fddc4774667c28'), ObjectId('656a871392fddc4774667c29'), ObjectId('656a871392fddc4774667c2a'), ObjectId('656a871392fddc4774667c2b'), ObjectId('656a871392fddc4774667c2c'), ObjectId('656a871392fddc4774667c2d'), ObjectId('656a871392fddc4774667c2e'), ObjectId('656a871392fddc4774667c2f'), ObjectId('656a871392fddc4774667c30'), ObjectId('656a871392fddc4774667c31'), ObjectId('656a871392fddc477466
# ...
